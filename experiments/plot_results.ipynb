# %%
import pandas as pd
import os
from experiments.utils import plot_mse, plot_time_maxmse_minxv, plot_weights_magging, plot_envwise_metric

# %% [markdown]
# ### MSE and MSPE

# %%
mse_path = os.path.join("results", "mse.csv")
mse_df = pd.read_csv(mse_path)

plot_mse(mse_df, out=False)

# %%
"""mspe_1_path = os.path.join("results", "mspe_1.csv")
mspe_1_df = pd.read_csv(mspe_1_path)

plot_mse(mspe_1_df)"""

# %%
"""mspe_2_path = os.path.join("results", "mspe_2.csv")
mspe_2_df = pd.read_csv(mspe_2_path)

plot_mse(mspe_2_df)"""

# %% [markdown]
# ### Runtime

# %%
runtime_path = os.path.join("results", "runtime.csv")
runtime_df = pd.read_csv(runtime_path)

plot_time_maxmse_minxv(runtime_df, comparison_metric=1)

# %% [markdown]
# ### MSE over training environments

# %%
maxmse_path = os.path.join("results", "max_mse.csv")
maxmse_df = pd.read_csv(maxmse_path)

plot_time_maxmse_minxv(maxmse_df, comparison_metric=2)

# %%
mseenvs_path = os.path.join("results", "mse_envs.csv")
mseenvs_df = pd.read_csv(mseenvs_path)

plot_envwise_metric(mseenvs_df)

# %% [markdown]
# ### Explained variance over training environments

# %%
minxplvar_path = os.path.join("results", "min_xpl_var.csv")
minxplvar_df = pd.read_csv(minxplvar_path)

plot_time_maxmse_minxv(minxplvar_df, comparison_metric=3)

# %%
xplvar_path = os.path.join("results", "xplvar_envs.csv")
xplvar_df = pd.read_csv(xplvar_path)

plot_envwise_metric(xplvar_df, mse=False)

# %% [markdown]
# ### Weights magging

# %%
wmag_path = os.path.join("results", "weights_magging.csv")
wmag_df = pd.read_csv(wmag_path)

plot_weights_magging(wmag_df)
